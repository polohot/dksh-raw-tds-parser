# %%
# GENERAL
from fastapi import FastAPI, File, Form, UploadFile, HTTPException, Body
from typing import Dict, Any
from typing import List, Annotated
import asyncio
import random
import tempfile
import shutil
import os
import fitz
import io
import base64
import datetime
import hashlib
import time
import anyio
import requests
import json
import simple_salesforce
from PIL import Image

# URLLIB3
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# AZURE AI DOCUMENT INTELLIGENCE
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient

# LOAD ENV VARIABLES
from dotenv import load_dotenv
load_dotenv()

# CUSTOM UTILS
from customutils import *

# %%
import pandas as pd

businessLine = 'FBI'

# DEFINE PATH
pdfpath = f"versionAchive/V0.9-alpha/testFiles/{businessLine}/"
# LIST ALL PDF
lspdf = [f for f in os.listdir(pdfpath) if f.endswith('.pdf')]
# DF
dfPDF = pd.DataFrame()
dfPDF['FULL_PATH'] = [pdfpath+f for f in lspdf]
dfPDF['FILE_SIZE_KB'] = dfPDF['FULL_PATH'].apply(lambda x: round(os.path.getsize(x) / 1024, 2))
dfPDF['FILE_NAME'] = lspdf
dfPDF['RESPONSE'] = None

dfPDF.head()
# Out:
#                                            FULL_PATH  FILE_SIZE_KB  \
# 0  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         98.78
# 1  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         18.05
# 2  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         94.88
# 3  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...        142.46
# 4  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         71.86
#
#                                            FILE_NAME RESPONSE
# 0           PIM000003031-Actimalt Liquid Regular.pdf     None
# 1    PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf     None
# 2                  PIM000003729-4. Acerola JC_TH.pdf     None
# 3                   PIM000003890-ACCELERZYME CPG.pdf     None
# 4  PIM000007436-Specification_1101103010101_Apple...     None

# %%
dfPDF = dfPDF.iloc[:5]
dfPDF.head()
# Out:
#                                            FULL_PATH  FILE_SIZE_KB  \
# 0  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         98.78
# 1  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         18.05
# 2  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         94.88
# 3  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...        142.46
# 4  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         71.86
#
#                                            FILE_NAME RESPONSE
# 0           PIM000003031-Actimalt Liquid Regular.pdf     None
# 1    PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf     None
# 2                  PIM000003729-4. Acerola JC_TH.pdf     None
# 3                   PIM000003890-ACCELERZYME CPG.pdf     None
# 4  PIM000007436-Specification_1101103010101_Apple...     None

# %%
for i in range(len(dfPDF)):
    try:
        full_path = dfPDF['FULL_PATH'][i]
        file_name = dfPDF['FILE_NAME'][i]
        url = "http://127.0.0.1:8000/v1_get_products_and_suppliers"
        #url = "https://web-app-basic-b3-dksh-raw-tds-parser-acgchxgncqdjb2ew.southeastasia-01.azurewebsites.net/v1_get_products_and_suppliers"
        input_secret = os.getenv('CUSTOM_SECRET1')
        files = [('inputListDocumentation', open(full_path, 'rb'))]
        data = {'inputSecret': input_secret}
        response = requests.post(url, files=files, data=data, verify=False)
        dfPDF['RESPONSE'].iat[i] = response.json()['products_and_suppliers']
        print('SUCCESS ', file_name)
    except:
        print('ERROR   ', file_name)
dfPDF.head()
# Out:
# SUCCESS  PIM000003031-Actimalt Liquid Regular.pdf
# SUCCESS  PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf
# SUCCESS  PIM000003729-4. Acerola JC_TH.pdf
# SUCCESS  PIM000003890-ACCELERZYME CPG.pdf
# SUCCESS  PIM000007436-Specification_1101103010101_Apple juice concentrate_Austria Juice Standard - Stock quality - Medium acidity.pdf
#                                            FULL_PATH  FILE_SIZE_KB  \
# 0  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         98.78
# 1  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         18.05
# 2  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         94.88
# 3  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...        142.46
# 4  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...         71.86
#
#                                            FILE_NAME  \
# 0           PIM000003031-Actimalt Liquid Regular.pdf
# 1    PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf
# 2                  PIM000003729-4. Acerola JC_TH.pdf
# 3                   PIM000003890-ACCELERZYME CPG.pdf
# 4  PIM000007436-Specification_1101103010101_Apple...
#
#                                             RESPONSE
# 0  [{'PRODUCT_NAME': 'ACTIMALT LIQUID REGULAR', '...
# 1  [{'PRODUCT_NAME': 'FAMB279 N&A BROWN SUGAR TYP...
# 2  [{'PRODUCT_NAME': 'Acerola juice concentrate, ...
# 3  [{'PRODUCT_NAME': 'Accelerzyme CPG BF', 'SUPPL...
# 4  [{'PRODUCT_NAME': 'Apple juice concentrate', '...

# %%
lsdf = []
for i in range(len(dfPDF)):
    row = dfPDF.iloc[i]
    if row['RESPONSE'] is None:
        continue
    for prod in row['RESPONSE']:
        df = pd.DataFrame({'FULL_PATH':[row['FULL_PATH']],
                           'FILE_NAME':[row['FILE_NAME']],
                           'PRODUCT':[prod['PRODUCT_NAME']],
                           'SUPPLIER':[prod['SUPPLIER_NAME']]})
        lsdf.append(df)
dfPROD = pd.concat(lsdf, ignore_index=True)
dfPROD['B64'] = [pdf_to_base64(x) for x in dfPROD['FULL_PATH']]
dfPROD['B64_LEN'] = [len(x) for x in dfPROD['B64']]
dfPROD.head()
# Out:
#                                            FULL_PATH  \
# 0  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 1  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 2  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 3  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 4  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
#
#                                            FILE_NAME  \
# 0           PIM000003031-Actimalt Liquid Regular.pdf
# 1    PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf
# 2                  PIM000003729-4. Acerola JC_TH.pdf
# 3                   PIM000003890-ACCELERZYME CPG.pdf
# 4  PIM000007436-Specification_1101103010101_Apple...
#
#                                         PRODUCT                   SUPPLIER  \
# 0                       ACTIMALT LIQUID REGULAR                    Muntons
# 1               FAMB279 N&A BROWN SUGAR TYPE FL         WILD Flavors, Inc.
# 2  Acerola juice concentrate, clarified R=64-68    SVZ Tomaszow Sp. z o.o.
# 3                            Accelerzyme CPG BF  DSM Food Specialties B.V.
# 4                       Apple juice concentrate         AUSTRIA JUICE GmbH
#
#                                                  B64  B64_LEN
# 0  JVBERi0xLjUNCiW1tbW1DQoxIDAgb2JqDQo8PC9UeXBlL0...   134864
# 1  JVBERi0xLjUNJeLjz9MNCjE5IDAgb2JqDTw8L0xpbmVhcm...    24648
# 2  JVBERi0xLjQKJeLjz9MNCjEgMCBvYmoKPDwgCi9DcmVhdG...   129544
# 3  JVBERi0xLjQKJeLjz9MKCjEgMCBvYmoKPDwvVHlwZSAvQ2...   194512
# 4  JVBERi0xLjcKjp2jtMXW5/gKMiAwIG9iagpbL0lDQ0Jhc2...    98116

# %%
# dfPROD = dfPROD.iloc[:2]
# dfPROD

# %%
##############################
# OPTION1: USING FILE UPLOAD #
##############################

dfPROD['RESPONSE'] = None
for i in range(len(dfPROD)):
    try:
        row = dfPROD.iloc[i]
        full_path = row['FULL_PATH']
        file_name = row['FILE_NAME']
        url = "http://127.0.0.1:8000/v1_parse_pim_fields"
        # url = "https://web-app-basic-b3-dksh-raw-tds-parser-acgchxgncqdjb2ew.southeastasia-01.azurewebsites.net/v1_parse_pim_fields"
        data = {
            "inputProductName": row['PRODUCT'],
            "inputBusinessLine": businessLine,
            "inputSecret": os.getenv('CUSTOM_SECRET1'),
            # booleans sent as strings in multipart forms
            "inputWebSearch": "false",
            "inputParallel": "true"}
        files = [("inputListDocumentation", (file_name, open(row["FULL_PATH"], "rb"), "application/pdf"))]
        response = requests.post(url, data=data, files=files, timeout=300, verify=False)
        dfPROD['RESPONSE'].iat[i] = response.json()
        print('SUCCESS ', file_name)
    except:
        print('FAILURE ', file_name)
dfPROD
# Out:
# SUCCESS  PIM000003031-Actimalt Liquid Regular.pdf
# SUCCESS  PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf
# SUCCESS  PIM000003729-4. Acerola JC_TH.pdf
# SUCCESS  PIM000003890-ACCELERZYME CPG.pdf
# SUCCESS  PIM000007436-Specification_1101103010101_Apple juice concentrate_Austria Juice Standard - Stock quality - Medium acidity.pdf
#                                            FULL_PATH  \
# 0  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 1  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 2  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 3  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 4  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
#
#                                            FILE_NAME  \
# 0           PIM000003031-Actimalt Liquid Regular.pdf
# 1    PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf
# 2                  PIM000003729-4. Acerola JC_TH.pdf
# 3                   PIM000003890-ACCELERZYME CPG.pdf
# 4  PIM000007436-Specification_1101103010101_Apple...
#
#                                         PRODUCT                   SUPPLIER  \
# 0                       ACTIMALT LIQUID REGULAR                    Muntons
# 1               FAMB279 N&A BROWN SUGAR TYPE FL         WILD Flavors, Inc.
# 2  Acerola juice concentrate, clarified R=64-68    SVZ Tomaszow Sp. z o.o.
# 3                            Accelerzyme CPG BF  DSM Food Specialties B.V.
# 4                       Apple juice concentrate         AUSTRIA JUICE GmbH
#
#                                                  B64  B64_LEN  \
# 0  JVBERi0xLjUNCiW1tbW1DQoxIDAgb2JqDQo8PC9UeXBlL0...   134864
# 1  JVBERi0xLjUNJeLjz9MNCjE5IDAgb2JqDTw8L0xpbmVhcm...    24648
# 2  JVBERi0xLjQKJeLjz9MNCjEgMCBvYmoKPDwgCi9DcmVhdG...   129544
# 3  JVBERi0xLjQKJeLjz9MKCjEgMCBvYmoKPDwvVHlwZSAvQ2...   194512
# 4  JVBERi0xLjcKjp2jtMXW5/gKMiAwIG9iagpbL0lDQ0Jhc2...    98116
#
#                                             RESPONSE
# 0  {'inputProductName': 'ACTIMALT LIQUID REGULAR'...
# 1  {'inputProductName': 'FAMB279 N&A BROWN SUGAR ...
# 2  {'inputProductName': 'Acerola juice concentrat...
# 3  {'inputProductName': 'Accelerzyme CPG BF', 'in...
# 4  {'inputProductName': 'Apple juice concentrate'...

# %%
######################
# OPTION2: USING B64 #
######################

dfPROD['RESPONSE'] = None
for i in range(len(dfPROD)):
    try:
        row = dfPROD.iloc[i]
        full_path = row['FULL_PATH']
        file_name = row['FILE_NAME']
        pdf_base64 = row['B64']
        url = "http://127.0.0.1:8000/v1_parse_pim_fields_b64"
        # url = "https://web-app-basic-b3-dksh-raw-tds-parser-acgchxgncqdjb2ew.southeastasia-01.azurewebsites.net/v1_parse_pim_fields_b64"
        data = {
            "inputProductName": row['PRODUCT'],
            "inputBusinessLine": businessLine,
            "inputSecret": os.getenv('CUSTOM_SECRET1'),
            "inputListDocumentationB64": [pdf_base64],
            "inputWebSearch": "false",
            "inputParallel": "true"}
        response = requests.post(url, data=data, timeout=300, verify=False)
        dfPROD['RESPONSE'].iat[i] = response.json()
        print('SUCCESS ', file_name, len(pdf_base64))
    except:
        print('FAILURE ', file_name)
dfPROD
# Out:
# SUCCESS  PIM000003031-Actimalt Liquid Regular.pdf 134864
# SUCCESS  PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf 24648
# SUCCESS  PIM000003729-4. Acerola JC_TH.pdf 129544
# SUCCESS  PIM000003890-ACCELERZYME CPG.pdf 194512
# SUCCESS  PIM000007436-Specification_1101103010101_Apple juice concentrate_Austria Juice Standard - Stock quality - Medium acidity.pdf 98116
#                                            FULL_PATH  \
# 0  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 1  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 2  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 3  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
# 4  versionAchive/V0.9-alpha/testFiles/FBI/PIM0000...
#
#                                            FILE_NAME  \
# 0           PIM000003031-Actimalt Liquid Regular.pdf
# 1    PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf
# 2                  PIM000003729-4. Acerola JC_TH.pdf
# 3                   PIM000003890-ACCELERZYME CPG.pdf
# 4  PIM000007436-Specification_1101103010101_Apple...
#
#                                         PRODUCT                   SUPPLIER  \
# 0                       ACTIMALT LIQUID REGULAR                    Muntons
# 1               FAMB279 N&A BROWN SUGAR TYPE FL         WILD Flavors, Inc.
# 2  Acerola juice concentrate, clarified R=64-68    SVZ Tomaszow Sp. z o.o.
# 3                            Accelerzyme CPG BF  DSM Food Specialties B.V.
# 4                       Apple juice concentrate         AUSTRIA JUICE GmbH
#
#                                                  B64  B64_LEN  \
# 0  JVBERi0xLjUNCiW1tbW1DQoxIDAgb2JqDQo8PC9UeXBlL0...   134864
# 1  JVBERi0xLjUNJeLjz9MNCjE5IDAgb2JqDTw8L0xpbmVhcm...    24648
# 2  JVBERi0xLjQKJeLjz9MNCjEgMCBvYmoKPDwgCi9DcmVhdG...   129544
# 3  JVBERi0xLjQKJeLjz9MKCjEgMCBvYmoKPDwvVHlwZSAvQ2...   194512
# 4  JVBERi0xLjcKjp2jtMXW5/gKMiAwIG9iagpbL0lDQ0Jhc2...    98116
#
#                                             RESPONSE
# 0  {'inputProductName': 'ACTIMALT LIQUID REGULAR'...
# 1  {'inputProductName': 'FAMB279 N&A BROWN SUGAR ...
# 2  {'inputProductName': 'Acerola juice concentrat...
# 3  {'inputProductName': 'Accelerzyme CPG BF', 'in...
# 4  {'inputProductName': 'Apple juice concentrate'...

# %% [markdown]
# # REARRANGE

# %%
dfPROD2 = dfPROD.copy()

keys = list(dfPROD2['RESPONSE'].iat[0].keys())
for key in keys:
    dfPROD2[key] = [x[key] for x in dfPROD2['RESPONSE']]

lscol = ['FILE_NAME', 'PRODUCT',   
       'gpt_manufacturer_or_supplier_answer',
       'gpt_manufacturer_or_supplier_reason',
       'gpt_select_industry_cluster_answer',
       'gpt_select_industry_cluster_reason', 'gpt_select_compositions_answer',
       'gpt_select_compositions_reason', 'gpt_select_functions_answer',
       'gpt_select_functions_reason', 'gpt_select_applications_answer',
       'gpt_select_applications_reason', 'gpt_cas_from_doc_answer',
       'gpt_cas_from_doc_reason', 'gpt_physical_form_answer',
       'gpt_physical_form_reason', 'gpt_gen_product_description',
       'gpt_recommended_dosage_answer', 'gpt_recommended_dosage_reason',
       'gpt_certifications_answer', 'gpt_certifications_reason',
       'gpt_claims_answer', 'gpt_claims_reason', 'gpt_health_benefits_answer',
       'gpt_health_benefits_reason']
dfPROD2 = dfPROD2[lscol]
dfPROD2.to_excel('tmp.xlsx', index=False)

dfPROD2
# Out:
#                                            FILE_NAME  \
# 0           PIM000003031-Actimalt Liquid Regular.pdf
# 1    PIM000003047-8. FAMB279 BROWN SUGAR TYPE FL.pdf
# 2                  PIM000003729-4. Acerola JC_TH.pdf
# 3                   PIM000003890-ACCELERZYME CPG.pdf
# 4  PIM000007436-Specification_1101103010101_Apple...
#
#                                         PRODUCT  \
# 0                       ACTIMALT LIQUID REGULAR
# 1               FAMB279 N&A BROWN SUGAR TYPE FL
# 2  Acerola juice concentrate, clarified R=64-68
# 3                            Accelerzyme CPG BF
# 4                       Apple juice concentrate
#
#   gpt_manufacturer_or_supplier_answer  \
# 0                             Muntons
# 1                  WILD Flavors, Inc.
# 2             SVZ Tomaszow Sp. z o.o.
# 3           DSM Food Specialties B.V.
# 4                  AUSTRIA JUICE GmbH
#
#                  gpt_manufacturer_or_supplier_reason  \
# 0  The document header and product specification ...
# 1  The product specification document for FAMB279...
# 2  The product specification document for Acerola...
# 3  The product specification sheet for Accelerzym...
# 4  The document is a product specification for Ap...
#
#                   gpt_select_industry_cluster_answer  \
# 0                            [Beverage & Dairy (BD)]
# 1  [Beverage & Dairy (BD), Confectionary & Bakery...
# 2  [Beverage & Dairy (BD), Food Supplements & Nut...
# 3             [Processed Food & Food Service (PFFS)]
# 4                            [Beverage & Dairy (BD)]
#
#                   gpt_select_industry_cluster_reason  \
# 0  Selected Beverage & Dairy (BD) because the pro...
# 1  Selected Beverage & Dairy (BD), Confectionary ...
# 2  Selected Beverage & Dairy (BD) because the pro...
# 3  Selected Processed Food & Food Service (PFFS) ...
# 4  Selected Beverage & Dairy (BD) because the pro...
#
#                       gpt_select_compositions_answer  \
# 0             [Cereals/Gluten, Sugars/Carbohydrates]
# 1  [Gum Arabic, Maltodextrin, Nature Identical Fl...
# 2  [Fruit juices and concentrates, Vitamins, Acid...
# 3                        [Protease enzyme, Glycerol]
# 4                          [Fruit juice, Malic acid]
#
#                       gpt_select_compositions_reason  \
# 0  Selected Cereals/Gluten because the product co...
# 1  Selected all listed ingredients because they a...
# 2  Selected 'Fruit juices and concentrates' becau...
# 3  Selected Protease enzyme because the product i...
# 4  Selected 'Fruit juice' because the product is ...
#
#                          gpt_select_functions_answer  \
# 0  [Dietary Fiber, Flavouring & Flavour Modulatio...
# 1  [Carrier & Bulking Agent, Colour & Colour Rete...
# 2  [Acidity Regulator, Antioxidant, Colour & Colo...
# 3                           [Food Enzyme, Humectant]
# 4                                [Acidity Regulator]
#
#                          gpt_select_functions_reason  ...  \
# 0  Selected Dietary Fiber because the document li...  ...
# 1  Selected Carrier & Bulking Agent because ingre...  ...
# 2  Selected Acidity Regulator because the product...  ...
# 3  Selected Food Enzyme because the product is de...  ...
# 4  Selected Acidity Regulator because the documen...  ...
#
#                             gpt_physical_form_reason  \
# 0  Selected Liquid because the product is describ...
# 1  Selected Powder because the Appearance is desc...
# 2  Selected Liquid because the product is describ...
# 3  Selected Liquid because the product descriptio...
# 4  Selected Liquid because the document mentions ...
#
#                          gpt_gen_product_description  \
# 0  ACTIMALT LIQUID REGULAR is a viscous yellow-br...
# 1  FAMB279 N&A BROWN SUGAR TYPE FL is a light bro...
# 2  Acerola juice concentrate, clarified R=64-68 f...
# 3  Accelerzyme CPG BF is a liquid carboxypeptidas...
# 4  Apple juice concentrate from AUSTRIA JUICE Gmb...
#
#   gpt_recommended_dosage_answer  \
# 0                           N/A
# 1                           N/A
# 2                           N/A
# 3                           N/A
# 4                           N/A
#
#                        gpt_recommended_dosage_reason  \
# 0  No recommended dosage instructions are mention...
# 1  No recommended dosage instructions are mention...
# 2  No recommended dosage instructions are mention...
# 3  No recommended dosage instructions are mention...
# 4  No recommended dosage instructions are mention...
#
#                            gpt_certifications_answer  \
# 0                                                 []
# 1                                   [GRAS, FEMAGRAS]
# 2                                                 []
# 3  [ISO, CODEX, JECFA, HALAL, JAKIM, MUI, Kosher,...
# 4                                                 []
#
#                            gpt_certifications_reason   gpt_claims_answer  \
# 0  No certifications related to ACTIMALT LIQUID R...                  []
# 1  Selected GRAS, FEMAGRAS because the document s...                  []
# 2  No certifications related to the product Acero...                  []
# 3  Selected ISO because the document states analy...  [Bio-Fermentation]
# 4  No certifications related to Apple juice conce...                  []
#
#                                    gpt_claims_reason  \
# 0  No mention of fermentation process or bio-ferm...
# 1  No mention of bio-fermentation, meat or dairy ...
# 2  No mention of bio-fermentation, meat or dairy ...
# 3  Selected Bio-Fermentation because the product ...
# 4  No mention of bio-fermentation processes, meat...
#
#   gpt_health_benefits_answer  \
# 0                         []
# 1                         []
# 2                         []
# 3                         []
# 4                         []
#
#                           gpt_health_benefits_reason
# 0  No applicable health benefits because product ...
# 1  No applicable health benefits because product ...
# 2  No applicable health benefits because product ...
# 3  No applicable health benefits because product ...
# 4  No applicable health benefits because product ...
#
# [5 rows x 25 columns]

# %%
dfPROD2.columns
# Out:
# Index(['FULL_PATH', 'FILE_NAME', 'PRODUCT', 'SUPPLIER', 'B64', 'B64_LEN',
#        'RESPONSE', 'inputProductName', 'inputBusinessLine',
#        'inputListDocumentation', 'inputSecret', 'inputWebSearch',
#        'inputParallel', 'stg_lsTempFile', 'stg_businessLineStr',
#        'stg_hashinputProductName', 'stg_hashinputBusinessLine',
#        'stg_hashinputListDocumentation', 'stg_hashCombined',
#        'stg_lsParsedText', 'stg_parsedText', 'stg_lsBase64',
#        'gpt_manufacturer_or_supplier_answer',
#        'gpt_manufacturer_or_supplier_reason', 'gpt_composition_search_answer',
#        'gpt_function_search_answer', 'gpt_application_search_answer',
#        'gpt_combined_web_search', 'gpt_text_of_this_product_only_answer',
#        'gpt_select_industry_cluster_answer',
#        'gpt_select_industry_cluster_reason', 'gpt_select_compositions_answer',
#        'gpt_select_compositions_reason', 'gpt_select_functions_answer',
#        'gpt_select_functions_reason', 'gpt_select_applications_answer',
#        'gpt_select_applications_reason', 'gpt_cas_from_doc_answer',
#        'gpt_cas_from_doc_reason', 'gpt_physical_form_answer',
#        'gpt_physical_form_reason', 'gpt_gen_product_description',
#        'gpt_recommended_dosage_answer', 'gpt_recommended_dosage_reason',
#        'gpt_certifications_answer', 'gpt_certifications_reason',
#        'gpt_claims_answer', 'gpt_claims_reason', 'gpt_health_benefits_answer',
#        'gpt_health_benefits_reason', 'time_start', 'time_end',
#        'time_duration'],
#       dtype='object')

# %%
list(dfPROD['RESPONSE'].iat[0].keys())
# Out:
# ['inputProductName',
#  'inputBusinessLine',
#  'inputListDocumentation',
#  'inputSecret',
#  'inputWebSearch',
#  'inputParallel',
#  'stg_lsTempFile',
#  'stg_businessLineStr',
#  'stg_hashinputProductName',
#  'stg_hashinputBusinessLine',
#  'stg_hashinputListDocumentation',
#  'stg_hashCombined',
#  'stg_lsParsedText',
#  'stg_parsedText',
#  'stg_lsBase64',
#  'gpt_manufacturer_or_supplier_answer',
#  'gpt_manufacturer_or_supplier_reason',
#  'gpt_composition_search_answer',
#  'gpt_function_search_answer',
#  'gpt_application_search_answer',
#  'gpt_combined_web_search',
#  'gpt_text_of_this_product_only_answer',
#  'gpt_select_industry_cluster_answer',
#  'gpt_select_industry_cluster_reason',
#  'gpt_select_compositions_answer',
#  'gpt_select_compositions_reason',
#  'gpt_select_functions_answer',
#  'gpt_select_functions_reason',
#  'gpt_select_applications_answer',
#  'gpt_select_applications_reason',
#  'gpt_cas_from_doc_answer',
#  'gpt_cas_from_doc_reason',
#  'gpt_physical_form_answer',
#  'gpt_physical_form_reason',
#  'gpt_gen_product_description',
#  'gpt_recommended_dosage_answer',
#  'gpt_recommended_dosage_reason',
#  'gpt_certifications_answer',
#  'gpt_certifications_reason',
#  'gpt_claims_answer',
#  'gpt_claims_reason',
#  'gpt_health_benefits_answer',
#  'gpt_health_benefits_reason',
#  'time_start',
#  'time_end',
#  'time_duration']
