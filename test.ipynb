# %%
import os
import requests
import json 

from dotenv import load_dotenv
load_dotenv()

from customutils import *

# %%
parsed_text = """{"pages":[{"page":1,"text":"                       polygal ag\n                       Weinfelderstrasse 13, 8560 Märstetten, Switzerland\n                       Tel.: +41 71 658 70 10, Fax +41 71 658 70 20\n                       info@polygal.ch, www.polygal.ch                                                     Personal Care\n Technical Datasheet\n Polycos A-2500 HV\n Polycos A-2500 is a multifunctional bio-based, non-ionic, transparent rheology modifier, film former, emulsion stabilizer,\n and conditioning polymer for skin care and hair care applications. It has good electrolyte tolerance and helps to provide skin\n conditioning. This polymer is compatible with electrolytes and is stable over a wide pH range. It's also suitable for\n hydroalcoholic systems.\n Composition            Non-ionic hydroxypropylated guar gum\n INCI-Name              Hydroxypropyl Guar\n Appearance             Off-white fine powder, transparent in solution\n Odour                  Characteristic\n Solubility             Cold processable in ambient water; also soluble in hydroalcoholic solutions\n                         (up to 80% ethanol / 60% Isopropanol) and polar solvents like glycerin or glycols\n Use level              0.2 - 5.0 %\n  Physical / chemical data                                                           Specifications                    Unit\n  Viscosity, 1% water                                                       2'400      –     3'500                     mPas\n  20 rpm (Brookfield RVT) 2 h. 25°C\n  Further typical physical data                                                      Specifications                    Unit\n  Loss on drying                                                            max.                       12               %\n  pH value of 1% water                                                      9.0        -               11.0\n  Granulation           < 75 μm                                             min.                       85               %\n  Transmittance (0.5%, 600 nm)                                              min.                       95               %\n  Microbiological values                                                             Specifications                    Unit\n  Total plate count                                                         max.                       100            cfu/g\n  Mould and yeast                                                           max.                       100            cfu/g\n  E. coli, Pseudomonas aeruginosa, Staphylococcus aureus,\n  Candida albicans*\n* according to internal analysis plan\n      Theindications in this technical datasheet correspond to our actual knowledge and experience. They describe our product in regard to quality and application but do neither\n      guarantee certain characteristics nor the suitability for a specific application. The user is responsible of all legal regulations including patent law. For warranty, liability and\n      quality conformity please consult our General Sales Conditions.\n V4.11–20241016/SL (CC 2024.10.01)                         5075208                                                     Page 1 of 2","md":"\n# polygal ag\n\nWeinfelderstrasse 13, 8560 Märstetten, Switzerland\n\nTel.: +41 71 658 70 10, Fax +41 71 658 70 20\n\ninfo@polygal.ch, www.polygal.ch\n\n\n\n# Personal Care\n\n# Technical Datasheet\n\n# Polycos A-2500 HV\n\nPolycos A-2500 is a multifunctional bio-based, non-ionic, transparent rheology modifier, film former, emulsion stabilizer, and conditioning polymer for skin care and hair care applications. It has good electrolyte tolerance and helps to provide skin conditioning. This polymer is compatible with electrolytes and is stable over a wide pH range. It's also suitable for hydroalcoholic systems.\n\n| Composition | Non-ionic hydroxypropylated guar gum                                                                                                                          |\n| ----------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------- |\n| INCI-Name   | Hydroxypropyl Guar                                                                                                                                            |\n| Appearance  | Off-white fine powder, transparent in solution                                                                                                                |\n| Odour       | Characteristic                                                                                                                                                |\n| Solubility  | Cold processable in ambient water; also soluble in hydroalcoholic solutions (up to 80% ethanol / 60% Isopropanol) and polar solvents like glycerin or glycols |\n| Use level   | 0.2 - 5.0 %                                                                                                                                                   |\n\n# Physical / chemical data\n\n| Specifications                                        | Unit               |\n| ----------------------------------------------------- | ------------------ |\n| Viscosity, 1% water 20 rpm (Brookfield RVT) 2 h. 25°C | 2'400 – 3'500 mPas |\n\n# Further typical physical data\n\n| Specifications               | Unit       |\n| ---------------------------- | ---------- |\n| Loss on drying               | max. 12 %  |\n| pH value of 1% water         | 9.0 - 11.0 |\n| Granulation < 75 μm          | min. 85 %  |\n| Transmittance (0.5%, 600 nm) | min. 95 %  |\n\n# Microbiological values\n\n| Specifications                                                             | Unit           |\n| -------------------------------------------------------------------------- | -------------- |\n| Total plate count                                                          | max. 100 cfu/g |\n| Mould and yeast                                                            | max. 100 cfu/g |\n| E. coli, Pseudomonas aeruginosa, Staphylococcus aureus, Candida albicans\\* |                |\n\n* according to internal analysis plan\n\nThe indications in this technical datasheet correspond to our actual knowledge and experience. They describe our product in regard to quality and application but do neither guarantee certain characteristics nor the suitability for a specific application. The user is responsible of all legal regulations including patent law. For warranty, liability and quality conformity please consult our General Sales Conditions.\n\nV4.11–20241016/SL (CC 2024.10.01) 5075208 Page 1 of 2","images":[{"name":"img_p0_1.png","height":38,"width":37,"x":56.65,"y":774.55,"original_width":null,"original_height":null,"type":null},{"name":"img_p0_2.png","height":24,"width":36,"x":106.5,"y":59.219999999999985,"original_width":null,"original_height":null,"type":null},{"name":"img_p0_3.png","height":15,"width":19,"x":462.01,"y":44.44700000000001,"original_width":null,"original_height":null,"type":null}],"charts":[],"tables":[],"layout":[],"items":[{"type":"heading","lvl":1,"value":"polygal ag","md":"# polygal ag","rows":null,"bBox":{"x":144.38,"y":21.12,"w":32.08,"h":7}},{"type":"text","lvl":null,"value":"Weinfelderstrasse 13, 8560 Märstetten, Switzerland\n\nTel.: +41 71 658 70 10, Fax +41 71 658 70 20\n\ninfo@polygal.ch, www.polygal.ch","md":"Weinfelderstrasse 13, 8560 Märstetten, Switzerland\n\nTel.: +41 71 658 70 10, Fax +41 71 658 70 20\n\ninfo@polygal.ch, www.polygal.ch","rows":null,"bBox":{"x":144.38,"y":30,"w":304.08,"h":546.19}},{"type":"heading","lvl":1,"value":"Personal Care","md":"# Personal Care","rows":null,"bBox":{"x":481.54,"y":52.8,"w":89.06,"h":14}},{"type":"heading","lvl":1,"value":"Technical Datasheet","md":"# Technical Datasheet","rows":null,"bBox":{"x":56.66,"y":143.66,"w":127.56,"h":14}},{"type":"heading","lvl":1,"value":"Polycos A-2500 HV","md":"# Polycos A-2500 HV","rows":null,"bBox":{"x":56.66,"y":160.22,"w":347.97,"h":396.17}},{"type":"text","lvl":null,"value":"Polycos A-2500 is a multifunctional bio-based, non-ionic, transparent rheology modifier, film former, emulsion stabilizer, and conditioning polymer for skin care and hair care applications. It has good electrolyte tolerance and helps to provide skin conditioning. This polymer is compatible with electrolytes and is stable over a wide pH range. It's also suitable for hydroalcoholic systems.","md":"Polycos A-2500 is a multifunctional bio-based, non-ionic, transparent rheology modifier, film former, emulsion stabilizer, and conditioning polymer for skin care and hair care applications. It has good electrolyte tolerance and helps to provide skin conditioning. This polymer is compatible with electrolytes and is stable over a wide pH range. It's also suitable for hydroalcoholic systems.","rows":null,"bBox":{"x":56.66,"y":247.85,"w":501.62,"h":308.54}},{"type":"table","lvl":null,"value":null,"md":"| Composition | Non-ionic hydroxypropylated guar gum                                                                                                                          |\n| ----------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------- |\n| INCI-Name   | Hydroxypropyl Guar                                                                                                                                            |\n| Appearance  | Off-white fine powder, transparent in solution                                                                                                                |\n| Odour       | Characteristic                                                                                                                                                |\n| Solubility  | Cold processable in ambient water; also soluble in hydroalcoholic solutions (up to 80% ethanol / 60% Isopropanol) and polar solvents like glycerin or glycols |\n| Use level   | 0.2 - 5.0 %                                                                                                                                                   |","rows":[["Composition","Non-ionic hydroxypropylated guar gum"],["INCI-Name","Hydroxypropyl Guar"],["Appearance","Off-white fine powder, transparent in solution"],["Odour","Characteristic"],["Solubility","Cold processable in ambient water; also soluble in hydroalcoholic solutions (up to 80% ethanol / 60% Isopropanol) and polar solvents like glycerin or glycols"],["Use level","0.2 - 5.0 %"]],"bBox":{"x":56.66,"y":320.45,"w":499.13,"h":466.51}},{"type":"heading","lvl":1,"value":"Physical / chemical data","md":"# Physical / chemical data","rows":null,"bBox":{"x":57.62,"y":463.87,"w":100.76,"h":9}},{"type":"table","lvl":null,"value":null,"md":"| Specifications                                        | Unit               |\n| ----------------------------------------------------- | ------------------ |\n| Viscosity, 1% water 20 rpm (Brookfield RVT) 2 h. 25°C | 2'400 – 3'500 mPas |","rows":[["Specifications","Unit"],["Viscosity, 1% water 20 rpm (Brookfield RVT) 2 h. 25°C","2'400 – 3'500 mPas"]],"bBox":{"x":375.79,"y":463.87,"w":166.15,"h":151.95}},{"type":"heading","lvl":1,"value":"Further typical physical data","md":"# Further typical physical data","rows":null,"bBox":{"x":57.62,"y":507.79,"w":118.4,"h":9}},{"type":"table","lvl":null,"value":null,"md":"| Specifications               | Unit       |\n| ---------------------------- | ---------- |\n| Loss on drying               | max. 12 %  |\n| pH value of 1% water         | 9.0 - 11.0 |\n| Granulation < 75 μm          | min. 85 %  |\n| Transmittance (0.5%, 600 nm) | min. 95 %  |","rows":[["Specifications","Unit"],["Loss on drying","max. 12 %"],["pH value of 1% water","9.0 - 11.0"],["Granulation < 75 μm","min. 85 %"],["Transmittance (0.5%, 600 nm)","min. 95 %"]],"bBox":{"x":57.62,"y":463.87,"w":484.32,"h":151.95}},{"type":"heading","lvl":1,"value":"Microbiological values","md":"# Microbiological values","rows":null,"bBox":{"x":57.62,"y":606.82,"w":92.08,"h":9}},{"type":"table","lvl":null,"value":null,"md":"| Specifications                                                             | Unit           |\n| -------------------------------------------------------------------------- | -------------- |\n| Total plate count                                                          | max. 100 cfu/g |\n| Mould and yeast                                                            | max. 100 cfu/g |\n| E. coli, Pseudomonas aeruginosa, Staphylococcus aureus, Candida albicans\\* |                |","rows":[["Specifications","Unit"],["Total plate count","max. 100 cfu/g"],["Mould and yeast","max. 100 cfu/g"],["E. coli, Pseudomonas aeruginosa, Staphylococcus aureus, Candida albicans*",""]],"bBox":{"x":51,"y":21.12,"w":519.6,"h":794.88}},{"type":"text","lvl":null,"value":"* according to internal analysis plan\n\nThe indications in this technical datasheet correspond to our actual knowledge and experience. They describe our product in regard to quality and application but do neither guarantee certain characteristics nor the suitability for a specific application. The user is responsible of all legal regulations including patent law. For warranty, liability and quality conformity please consult our General Sales Conditions.\n\nV4.11–20241016/SL (CC 2024.10.01) 5075208 Page 1 of 2","md":"* according to internal analysis plan\n\nThe indications in this technical datasheet correspond to our actual knowledge and experience. They describe our product in regard to quality and application but do neither guarantee certain characteristics nor the suitability for a specific application. The user is responsible of all legal regulations including patent law. For warranty, liability and quality conformity please consult our General Sales Conditions.\n\nV4.11–20241016/SL (CC 2024.10.01) 5075208 Page 1 of 2","rows":null,"bBox":{"x":51,"y":143.66,"w":518.84,"h":672.34}}],"status":"OK","links":[{"url":"mailto:info@polygal.ch","unsafeUrl":"mailto:info@polygal.ch","text":"info@polygal.ch,"},{"url":"http://www.polygal.ch/","unsafeUrl":"http://www.polygal.ch/","text":"www.polygal.ch"}],"width":595.56,"height":842.04,"triggeredAutoMode":false,"parsingMode":"accurate","structuredData":null,"noStructuredContent":false,"noTextContent":false},{"page":2,"text":" Technical Datasheet                                                                                                           polygal.ch\n Polycos A-2500 HV\n                                                                                                                   Personal Care\n Packing                                                               Regulations\n Multiwall polytreated paper bags of 25kg net                          This product is in accordance with the specifications of EU and\n                                                                       Swiss regulations for additives.\n Storage/Shelf life                                                    However, it should always be consulted that this product is in\nWhen the product is stored under dry and cool conditions,              compliance with the local regulations in force, particularly in\nin the unopened original package and in a well ventilated              the country where the product is to be used.\narea, the product can be used safely for minimum 24\nmonths. Reaching the 24 months a retest of the material\ncan be conducted to prolong the shelf life by 6 months.\n     Theindications in this technical datasheet correspond to our actual knowledge and experience. They describe our product in regard to quality and application but do neither\n     guarantee certain characteristics nor the suitability for a specific application. The user is responsible of all legal regulations including patent law. For warranty, liability and\n     quality conformity please consult our General Sales Conditions.\n V4.11–20241016/SL (CC 2024.10.01)                             5075208                                                         Page 2 of 2","md":"Technical Datasheet\n# Polycos A-2500 HV\n\n# Personal Care\n\n# Packing\n\nMultiwall polytreated paper bags of 25kg net\n\n# Regulations\n\nThis product is in accordance with the specifications of EU and Swiss regulations for additives.\n\nHowever, it should always be consulted that this product is in compliance with the local regulations in force, particularly in the country where the product is to be used.\n\n# Storage/Shelf life\n\nWhen the product is stored under dry and cool conditions, in the unopened original package and in a well ventilated area, the product can be used safely for minimum 24 months. Reaching the 24 months a retest of the material can be conducted to prolong the shelf life by 6 months.\n\nThe indications in this technical datasheet correspond to our actual knowledge and experience. They describe our product in regard to quality and application but do neither guarantee certain characteristics nor the suitability for a specific application. The user is responsible of all legal regulations including patent law. For warranty, liability and quality conformity please consult our General Sales Conditions.\n\nV4.11–20241016/SL (CC 2024.10.01) 5075208 Page 2 of 2\n","images":[],"charts":[],"tables":[],"layout":[],"items":[{"type":"text","lvl":null,"value":"Technical Datasheet","md":"Technical Datasheet","rows":null,"bBox":{"x":56.66,"y":20.52,"w":80.8,"h":9}},{"type":"heading","lvl":1,"value":"Polycos A-2500 HV","md":"# Polycos A-2500 HV","rows":null,"bBox":{"x":56.66,"y":32.4,"w":82.92,"h":9}},{"type":"heading","lvl":1,"value":"Personal Care","md":"# Personal Care","rows":null,"bBox":{"x":481.42,"y":49.2,"w":89.06,"h":14}},{"type":"heading","lvl":1,"value":"Packing","md":"# Packing","rows":null,"bBox":{"x":56.66,"y":106.58,"w":31,"h":9}},{"type":"text","lvl":null,"value":"Multiwall polytreated paper bags of 25kg net","md":"Multiwall polytreated paper bags of 25kg net","rows":null,"bBox":{"x":56.66,"y":118.58,"w":180.43,"h":9}},{"type":"heading","lvl":1,"value":"Regulations","md":"# Regulations","rows":null,"bBox":{"x":318.67,"y":106.58,"w":47,"h":9}},{"type":"text","lvl":null,"value":"This product is in accordance with the specifications of EU and Swiss regulations for additives.\n\nHowever, it should always be consulted that this product is in compliance with the local regulations in force, particularly in the country where the product is to be used.","md":"This product is in accordance with the specifications of EU and Swiss regulations for additives.\n\nHowever, it should always be consulted that this product is in compliance with the local regulations in force, particularly in the country where the product is to be used.","rows":null,"bBox":{"x":318.67,"y":106.58,"w":255.5,"h":66.6}},{"type":"heading","lvl":1,"value":"Storage/Shelf life","md":"# Storage/Shelf life","rows":null,"bBox":{"x":56.66,"y":142.58,"w":72.48,"h":9}},{"type":"text","lvl":null,"value":"When the product is stored under dry and cool conditions, in the unopened original package and in a well ventilated area, the product can be used safely for minimum 24 months. Reaching the 24 months a retest of the material can be conducted to prolong the shelf life by 6 months.\n\nThe indications in this technical datasheet correspond to our actual knowledge and experience. They describe our product in regard to quality and application but do neither guarantee certain characteristics nor the suitability for a specific application. The user is responsible of all legal regulations including patent law. For warranty, liability and quality conformity please consult our General Sales Conditions.\n\nV4.11–20241016/SL (CC 2024.10.01) 5075208 Page 2 of 2","md":"When the product is stored under dry and cool conditions, in the unopened original package and in a well ventilated area, the product can be used safely for minimum 24 months. Reaching the 24 months a retest of the material can be conducted to prolong the shelf life by 6 months.\n\nThe indications in this technical datasheet correspond to our actual knowledge and experience. They describe our product in regard to quality and application but do neither guarantee certain characteristics nor the suitability for a specific application. The user is responsible of all legal regulations including patent law. For warranty, liability and quality conformity please consult our General Sales Conditions.\n\nV4.11–20241016/SL (CC 2024.10.01) 5075208 Page 2 of 2","rows":null,"bBox":{"x":55.56,"y":20.52,"w":515.72,"h":795.48}}],"status":"OK","links":[],"width":595.56,"height":842.04,"triggeredAutoMode":false,"parsingMode":"accurate","structuredData":null,"noStructuredContent":false,"noTextContent":false}],"job_metadata":{"job_pages":0,"job_auto_mode_triggered_pages":0,"job_is_cache_hit":true},"file_name":"/tmp/tmpe6am2g8s.pdf","job_id":"89acf080-6882-423f-8538-2dad2e4fcfd4","is_done":false,"error":null}"""

# %%
body = buildStructuredOutputBody(parsed_text, 'Polycos RS', 'Polygal AG')

# %%
# CALL API
import requests
response = requests.post("https://ancient-almeda-personal-personal-22e19704.koyeb.app/openai",                                         
                            json=body, 
                            params={"apikey": os.getenv('OPENAI_API_KEY')},
                            verify=False)
# Out:
# c:\Users\khunakorn.l\AppData\Local\miniconda3\envs\dksh-raw-tds-parser\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ancient-almeda-personal-personal-22e19704.koyeb.app'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
obj = response.json()['choices'][0]['message']['content']
parsed = json.loads(obj)
print(json.dumps(parsed, indent=2))
# Out:
# '{"manufacturing_site_address":"Weinfelderstrasse 13, 8560 Märstetten, Switzerland","manufacturing_country":"Switzerland","manufacturer_article_number":"Not Specified","physical_location_of_goods":"Switzerland","contains_animal_origin":"Not Specified","contains_vegetal_origin":"Yes","contains_palm":"Not Specified","contains_mineral_origin":"Not Specified","contains_conflict_minerals":"Not Specified","contains_synthetic_origin":"Not Specified","other_specified_origin":"Not Specified","outer_packaging_unit":"Multiwall polytreated paper bags","outer_packaging_material":"Paper","un_homologated_outer_packaging":"Not Specified","inner_packaging_unit":"Not Specified","inner_packaging_material":"Not Specified","gross_weight_kg":"Not Specified","net_weight_kg":"25kg","dimensions_lwh":"Not Specified","volume_m3":"Not Specified","pallet_type_material":"Not Specified","storage_conditions":"Store under dry and cool conditions, in unopened original package and well ventilated area","transport_cond
# ...

# %%
parsed = json.loads(obj)
print(json.dumps(parsed, indent=2))
# Out:
# {
#   "manufacturing_site_address": "Weinfelderstrasse 13, 8560 M\u00e4rstetten, Switzerland",
#   "manufacturing_country": "Switzerland",
#   "manufacturer_article_number": "Not Specified",
#   "physical_location_of_goods": "Switzerland",
#   "contains_animal_origin": "Not Specified",
#   "contains_vegetal_origin": "Yes",
#   "contains_palm": "Not Specified",
#   "contains_mineral_origin": "Not Specified",
#   "contains_conflict_minerals": "Not Specified",
#   "contains_synthetic_origin": "Not Specified",
#   "other_specified_origin": "Not Specified",
#   "outer_packaging_unit": "Multiwall polytreated paper bags",
#   "outer_packaging_material": "Paper",
#   "un_homologated_outer_packaging": "Not Specified",
#   "inner_packaging_unit": "Not Specified",
#   "inner_packaging_material": "Not Specified",
#   "gross_weight_kg": "Not Specified",
#   "net_weight_kg": "25kg",
#   "dimensions_lwh": "Not Specified",
#   "volume_m3": "Not Specified",
# ...
