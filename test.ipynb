# %%
import os
import io
import pandas as pd
import streamlit as st
import requests
import tempfile
import json
import base64
import fitz
from PIL import Image

from customutils import *

# Load environment variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from openai import AzureOpenAI

client = AzureOpenAI(
    api_version="2024-12-01-preview",
    azure_endpoint="https://azure-ai-services-main01.cognitiveservices.azure.com/",
    api_key='xx',
)

# %%
import os
from openai import AzureOpenAI

endpoint = "https://azure-ai-services-main01.cognitiveservices.azure.com/"
model_name = "gpt-4o"
deployment = "azure-ai-services-main01-gpt-4o-main01"

subscription_key = 'xx'
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        }
    ],
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# Paris is an incredible city with so much to offer! Here are the must-see attractions and activities to make the most of your trip:
#
# ### Iconic Landmarks
# 1. **Eiffel Tower** - A symbol of Paris, you can enjoy stunning views from the top or picnic in the park nearby.
# 2. **Louvre Museum** - One of the world’s most famous museums, home to iconic works like the Mona Lisa and Venus de Milo.
# 3. **Notre-Dame Cathedral** - A stunning Gothic masterpiece (though restoration may still be ongoing), with breathtaking architecture.
# 4. **Arc de Triomphe and Champs-Élysées** - A grand monument honoring war heroes and Paris' most famous shopping boulevard.
# 5. **Sacré-Cœur Basilica** - Perched on Montmartre hill, offering panoramic views and a charming artistic vibe.
#
# ### Cultural Spots
# 6. **Musée d’Orsay** - A museum housed in a former train station with an impressive collection of Impressionist masterpieces.
# 7. **Centre Pompidou** - A modern art museum with an exciting design and fascinating exhibitions.
# 8. **Palace of Versailles** - A short trip from Paris, this lavish palace is a must-see for its opulent rooms and expansive gardens.
#
# ### Charming Neighborhoods
# 9. **Le Marais** - A historic district filled with narrow streets, chic boutiques, galleries, and unique eateries.
# 10. **Montmartre** - Known for its bohemian history, artists, and picturesque streets. Look out for the Wall of Love (Le Mur des Je T’aime).
# 11. **Latin Quarter** - A lively area full of bookstores, cafes, and student energy near the Sorbonne.
#
# ### Scenic Spots
# 12. **Seine River Cruise** - A boat ride is a relaxing way to see iconic sights like Notre-Dame, the Eiffel Tower, and the bridges of Paris.
# 13. **Jardin des Tuileries** - Lovely gardens perfect for a peaceful stroll near the Louvre.
# 14. **Luxembourg Gardens** - A charming park popular for picnics and people-watching.
# 15. **Canal Saint-Martin** - A trendy area where you can walk or have a meal beside the canal.
#
# ### Unique Experiences
# 16. **Catacombs of Paris** - Explore the underground tunnels filled with history and mystery.
# 17. **Opera Garnier** - A stunning opera house with exquisite architecture, even if you don’t see a show.
# 18. **Père Lachaise Cemetery** - Pay homage to famous figures like Jim Morrison, Oscar Wilde, and Edith Piaf.
#
# ### Food and Shopping
# 19. **French Cuisine** - Indulge in escargot, coq au vin, French onion soup, and croissants at Parisian cafes and restaurants.
# 20. **Pastries and Desserts** - Try macarons from Ladurée, eclairs, and delectable pastries from renowned bakeries.
# 21. **Shopping** - Browse high-end fashion at flagship stores along Champs-Élysées or explore quirky boutiques in Le Marais.
#
# ### Hidden Gems
# 22. **Musée de l’Orangerie** - Admire Monet’s Water Lilies, a quiet yet awe-inspiring spot.
# 23. **Panthéon** - Visit the final resting place of notable figures like Voltaire and Victor Hugo while marveling at its neoclassical architecture.
# 24. **La Petite Ceinture** - An abandoned railway turned into a hidden green walking path.
#
# ### Tips:
# - Consider buying a **Paris Museum Pass** for access to multiple attractions across the city.
# - Walk as much as possible—Paris is best explored on foot to soak in its charming streets.
#
# Let me know if you'd like tailored recommendations for specific interests or time constraints! Have an amazing time! 😊
